# %%
import os
import numpy as np
import pydicom
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.nn.functional as F
import matplotlib.pyplot as plt
import cv2
import h5py
from torchinfo import summary
from torchvision import transforms
from sklearn.model_selection import train_test_split
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim

# %%
# Directorio donde están los estudios (cada subcarpeta es un estudio MRI)
dicom_root_dir = './Imagenes_Finales/176X256X256'

# Función para cargar y normalizar un volumen 3D
def load_dicom_volume(dicom_dir):
    dicom_files = sorted([os.path.join(dicom_dir, f) for f in os.listdir(dicom_dir) if f.endswith(".dcm")],
                         key=lambda f: float(pydicom.dcmread(f).InstanceNumber))
    
    volume = np.array([pydicom.dcmread(f).pixel_array for f in dicom_files], dtype=np.float32)
    volume = (volume - np.min(volume)) / (np.max(volume) - np.min(volume) + 1e-7)  # Normalización [0,1]
    return volume

# %%
# Cargar todos los estudios
study_dirs = [os.path.join(dicom_root_dir, d) for d in os.listdir(dicom_root_dir) if os.path.isdir(os.path.join(dicom_root_dir, d))]
volumes = [load_dicom_volume(study_dir) for study_dir in study_dirs]

# %%
print(f"Se cargaron {len(volumes)} estudios.")
# Out:
# Se cargaron 30 estudios.

# %%
# Generar baja resolución
def low_res_volume(volume, factor=0.5):
    d, h, w = volume.shape
    low_res = np.array([cv2.resize(cv2.resize(slice, (int(w * factor), int(h * factor)), interpolation=cv2.INTER_AREA),
                                   (w, h), interpolation=cv2.INTER_LINEAR) for slice in volume])
    return low_res

# %%
low_res_volumes = [low_res_volume(vol) for vol in volumes]

# %%
print(f"Dimensiones del primer volumen HR: {volumes[0].shape}")
print(f"Dimensiones del primer volumen LR: {low_res_volumes[0].shape}")
# Out:
# Dimensiones del primer volumen HR: (176, 256, 256)
# Dimensiones del primer volumen LR: (176, 256, 256)

# %%
# Visualización de un corte específico
def visualize_slices(original, low_res, slice_idx):
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(original[slice_idx], cmap='gray')
    plt.title("Original")
    plt.subplot(1, 2, 2)
    plt.imshow(low_res[slice_idx], cmap='gray')
    plt.title("Low Resolution")
    plt.show()

# %%
# Elegir un estudio y un corte arbitrario
study_idx = 7
slice_idx = volumes[study_idx].shape[0] // 2  # Corte intermedio
visualize_slices(volumes[study_idx], low_res_volumes[study_idx], slice_idx)

# %%
# División en entrenamiento y validación
train_vols, val_vols, train_lr, val_lr = train_test_split(volumes, low_res_volumes, test_size=0.1, random_state=42)

# %%
# Extraer patches 3D
def extract_patches(volume, patch_size=(64, 64, 64), stride=32):
    d, h, w = volume.shape
    return [volume[z:z+patch_size[0], y:y+patch_size[1], x:x+patch_size[2]]
            for z in range(0, d - patch_size[0] + 1, stride)
            for y in range(0, h - patch_size[1] + 1, stride)
            for x in range(0, w - patch_size[2] + 1, stride)]

# %%
train_patches = [(p, hr) for vol_lr, vol_hr in zip(train_lr, train_vols) for p, hr in zip(extract_patches(vol_lr), extract_patches(vol_hr))]
val_patches = [(p, hr) for vol_lr, vol_hr in zip(val_lr, val_vols) for p, hr in zip(extract_patches(vol_lr), extract_patches(vol_hr))]

# %%
# Dataset
class MRI3DPatchDataset(data.Dataset):
    def __init__(self, patch_pairs):
        self.patch_pairs = patch_pairs
    
    def __len__(self):
        return len(self.patch_pairs)
    
    def __getitem__(self, idx):
        lr_patch, hr_patch = self.patch_pairs[idx]
        return torch.tensor(lr_patch, dtype=torch.float32).unsqueeze(0), torch.tensor(hr_patch, dtype=torch.float32).unsqueeze(0)

# %%
dataset_train = MRI3DPatchDataset(train_patches)
dataset_val = MRI3DPatchDataset(val_patches)

# %%
# DataLoader
dataloader_train = data.DataLoader(dataset_train, batch_size=4, shuffle=True, num_workers=0, pin_memory=True)
dataloader_val = data.DataLoader(dataset_val, batch_size=4, shuffle=False, num_workers=0, pin_memory=True)

# %%
# Modelo EDSR3D
class ResidualBlock3D(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv3d(channels, channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv3d(channels, channels, kernel_size=3, padding=1)
        )

    def forward(self, x):
        return x + self.block(x)

class EDSR3D(nn.Module):
    def __init__(self, in_channels=1, out_channels=1, num_blocks=4, base_channels=32):
        super().__init__()
        self.head = nn.Conv3d(in_channels, base_channels, kernel_size=3, padding=1)
        self.body = nn.Sequential(*[ResidualBlock3D(base_channels) for _ in range(num_blocks)])
        self.tail = nn.Conv3d(base_channels, out_channels, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.head(x)
        res = self.body(x)
        return self.tail(x + res)

# %%
# Configuración del dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Inicializar modelo 
model = EDSR3D().to(device)
# Summary del modelo
summary(model, input_size=(1, 1, 64, 64, 64))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# EDSR3D                                   [1, 1, 64, 64, 64]        --
# ├─Conv3d: 1-1                            [1, 32, 64, 64, 64]       896
# ├─Sequential: 1-2                        [1, 32, 64, 64, 64]       --
# │    └─ResidualBlock3D: 2-1              [1, 32, 64, 64, 64]       --
# │    │    └─Sequential: 3-1              [1, 32, 64, 64, 64]       55,360
# │    └─ResidualBlock3D: 2-2              [1, 32, 64, 64, 64]       --
# │    │    └─Sequential: 3-2              [1, 32, 64, 64, 64]       55,360
# │    └─ResidualBlock3D: 2-3              [1, 32, 64, 64, 64]       --
# │    │    └─Sequential: 3-3              [1, 32, 64, 64, 64]       55,360
# │    └─ResidualBlock3D: 2-4              [1, 32, 64, 64, 64]       --
# │    │    └─Sequential: 3-4              [1, 32, 64, 64, 64]       55,360
# ├─Conv3d: 1-3                            [1, 1, 64, 64, 64]        865
# ==========================================================================================
# Total params: 223,201
# Trainable params: 223,201
# Non-trainable params: 0
# Total mult-adds (G): 58.51
# ==========================================================================================
# Input size (MB): 1.05
# Forward/backward pass size (MB): 606.08
# Params size (MB): 0.89
# Estimated Total Size (MB): 608.02
# ==========================================================================================

# %%
# Inicializar función de pérdida, optimizador y scheduler
criterion = nn.L1Loss()
optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.8, patience=10, verbose=True)

# %%
num_epochs = 50
# Se crea la carpeta para guardar los checkpoints y las metricas
checkpoint_dir = "checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

# %%
# En el archivo h5 se guardan las metricas para realizar graficas posteriormente, sin tener que correr todo el entrenamiento de nuevo
h5_file = os.path.join(checkpoint_dir, "metrics.h5")
with h5py.File(h5_file, "w") as f:
    f.create_dataset("train_loss", (0,), maxshape=(None,))
    f.create_dataset("val_loss", (0,), maxshape=(None,))
    f.create_dataset("psnr_train", (0,), maxshape=(None,))
    f.create_dataset("ssim_train", (0,), maxshape=(None,))
    f.create_dataset("psnr_val", (0,), maxshape=(None,))
    f.create_dataset("ssim_val", (0,), maxshape=(None,))

# %%
print("Entrenamiento Iniciado")
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    total_psnr_train, total_ssim_train, count_train = 0, 0, 0

    for lr_patch, hr_patch in dataloader_train:
        lr_patch, hr_patch = lr_patch.to(device), hr_patch.to(device)
        optimizer.zero_grad()

        output = model(lr_patch)
        loss = criterion(output, hr_patch)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        batch_size = lr_patch.size(0)

        for i in range(batch_size):
            output_np = output[i].cpu().detach().numpy().squeeze()
            hr_np = hr_patch[i].cpu().detach().numpy().squeeze()
            total_psnr_train += psnr(hr_np, output_np, data_range=1)
            total_ssim_train += ssim(hr_np, output_np, data_range=1)
            count_train += 1

    avg_train_loss = train_loss / len(dataloader_train)
    avg_psnr_train = total_psnr_train / count_train
    avg_ssim_train = total_ssim_train / count_train

    # Validación
    model.eval()
    val_loss = 0.0
    total_psnr_val, total_ssim_val, count_val = 0, 0, 0

    with torch.no_grad():
        for lr_patch, hr_patch in dataloader_val:
            lr_patch, hr_patch = lr_patch.to(device), hr_patch.to(device)
            output = model(lr_patch)
            loss = criterion(output, hr_patch)
            val_loss += loss.item()

            batch_size = lr_patch.size(0)
            for i in range(batch_size):
                output_np = output[i].cpu().detach().numpy().squeeze()
                hr_np = hr_patch[i].cpu().detach().numpy().squeeze()
                total_psnr_val += psnr(hr_np, output_np, data_range=1)
                total_ssim_val += ssim(hr_np, output_np, data_range=1)
                count_val += 1

    avg_val_loss = val_loss / len(dataloader_val)
    avg_psnr_val = total_psnr_val / count_val
    avg_ssim_val = total_ssim_val / count_val

    print(f"Epoch [{epoch+1}/{num_epochs}] - "
          f"Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}, "
          f"PSNR Train: {avg_psnr_train:.2f}, PSNR Val: {avg_psnr_val:.2f}, "
          f"SSIM Train: {avg_ssim_train:.4f}, SSIM Val: {avg_ssim_val:.4f}")

    # Guardar en el archivo HDF5
    with h5py.File(h5_file, "a") as f:
        for key, value in zip(
            ["train_loss", "val_loss", "psnr_train", "ssim_train", "psnr_val", "ssim_val"],
            [avg_train_loss, avg_val_loss, avg_psnr_train, avg_ssim_train, avg_psnr_val, avg_ssim_val]
        ):
            dataset = f[key]
            dataset.resize((dataset.shape[0] + 1,))
            dataset[-1] = value

    # Guardar checkpoint del modelo
    torch.save(model.state_dict(), os.path.join(checkpoint_dir, f"srcnn3d_epoch_{epoch+1}.pth"))

    # Ajustar el learning rate
    scheduler.step(avg_val_loss)

print("Entrenamiento completado.")
# Out:
# Entrenamiento Iniciado
# Epoch [1/50] - Train Loss: 0.0133, Val Loss: 0.0121, PSNR Train: 34.68, PSNR Val: 35.01, SSIM Train: 0.9283, SSIM Val: 0.9499
# Epoch [2/50] - Train Loss: 0.0106, Val Loss: 0.0114, PSNR Train: 36.22, PSNR Val: 35.57, SSIM Train: 0.9563, SSIM Val: 0.9539
# Epoch [3/50] - Train Loss: 0.0102, Val Loss: 0.0109, PSNR Train: 36.63, PSNR Val: 36.01, SSIM Train: 0.9587, SSIM Val: 0.9580
# Epoch [4/50] - Train Loss: 0.0099, Val Loss: 0.0107, PSNR Train: 36.94, PSNR Val: 36.22, SSIM Train: 0.9597, SSIM Val: 0.9596
# Epoch [5/50] - Train Loss: 0.0097, Val Loss: 0.0105, PSNR Train: 37.17, PSNR Val: 36.43, SSIM Train: 0.9621, SSIM Val: 0.9605
# Epoch [6/50] - Train Loss: 0.0095, Val Loss: 0.0104, PSNR Train: 37.35, PSNR Val: 36.60, SSIM Train: 0.9640, SSIM Val: 0.9614
# Epoch [7/50] - Train Loss: 0.0094, Val Loss: 0.0102, PSNR Train: 37.50, PSNR Val: 36.74, SSIM Train: 0.9646, SSIM Val: 0.9621
# Epoch [8/50] - Train Loss: 0.0093, Val Loss: 0.0101, PSNR Train: 37.63, PSNR Val: 36.86, SSIM Train: 0.9652, SSIM Val: 0.9626
# Epoch [9/50] - Train Loss: 0.0092, Val Loss: 0.0100, PSNR Train: 37.76, PSNR Val: 36.96, SSIM Train: 0.9662, SSIM Val: 0.9631
# Epoch [10/50] - Train Loss: 0.0091, Val Loss: 0.0100, PSNR Train: 37.86, PSNR Val: 37.03, SSIM Train: 0.9668, SSIM Val: 0.9636
# Epoch [11/50] - Train Loss: 0.0090, Val Loss: 0.0100, PSNR Train: 37.92, PSNR Val: 37.07, SSIM Train: 0.9669, SSIM Val: 0.9640
# Epoch [12/50] - Train Loss: 0.0090, Val Loss: 0.0099, PSNR Train: 38.00, PSNR Val: 37.14, SSIM Train: 0.9675, SSIM Val: 0.9636
# Epoch [13/50] - Train Loss: 0.0089, Val Loss: 0.0099, PSNR Train: 38.05, PSNR Val: 37.16, SSIM Train: 0.9678, SSIM Val: 0.9642
# Epoch [14/50] - Train Loss: 0.0089, Val Loss: 0.0098, PSNR Train: 38.08, PSNR Val: 37.23, SSIM Train: 0.9678, SSIM Val: 0.9646
# Epoch [15/50] - Train Loss: 0.0088, Val Loss: 0.0098, PSNR Train: 38.14, PSNR Val: 37.27, SSIM Train: 0.9683, SSIM Val: 0.9647
# Epoch [16/50] - Train Loss: 0.0088, Val Loss: 0.0099, PSNR Train: 38.17, PSNR Val: 37.21, SSIM Train: 0.9683, SSIM Val: 0.9620
# Epoch [17/50] - Train Loss: 0.0088, Val Loss: 0.0097, PSNR Train: 38.21, PSNR Val: 37.32, SSIM Train: 0.9685, SSIM Val: 0.9648
# Epoch [18/50] - Train Loss: 0.0088, Val Loss: 0.0097, PSNR Train: 38.23, PSNR Val: 37.35, SSIM Train: 0.9686, SSIM Val: 0.9651
# Epoch [19/50] - Train Loss: 0.0088, Val Loss: 0.0097, PSNR Train: 38.25, PSNR Val: 37.33, SSIM Train: 0.9686, SSIM Val: 0.9650
# Epoch [20/50] - Train Loss: 0.0087, Val Loss: 0.0097, PSNR Train: 38.28, PSNR Val: 37.37, SSIM Train: 0.9688, SSIM Val: 0.9651
# Epoch [21/50] - Train Loss: 0.0087, Val Loss: 0.0097, PSNR Train: 38.27, PSNR Val: 37.40, SSIM Train: 0.9686, SSIM Val: 0.9654
# Epoch [22/50] - Train Loss: 0.0087, Val Loss: 0.0097, PSNR Train: 38.31, PSNR Val: 37.38, SSIM Train: 0.9690, SSIM Val: 0.9652
# Epoch [23/50] - Train Loss: 0.0087, Val Loss: 0.0096, PSNR Train: 38.34, PSNR Val: 37.43, SSIM Train: 0.9693, SSIM Val: 0.9655
# Epoch [24/50] - Train Loss: 0.0087, Val Loss: 0.0096, PSNR Train: 38.35, PSNR Val: 37.41, SSIM Train: 0.9692, SSIM Val: 0.9656
# Epoch [25/50] - Train Loss: 0.0087, Val Loss: 0.0096, PSNR Train: 38.37, PSNR Val: 37.44, SSIM Train: 0.9693, SSIM Val: 0.9655
# Epoch [26/50] - Train Loss: 0.0086, Val Loss: 0.0096, PSNR Train: 38.39, PSNR Val: 37.45, SSIM Train: 0.9694, SSIM Val: 0.9654
# Epoch [27/50] - Train Loss: 0.0086, Val Loss: 0.0096, PSNR Train: 38.40, PSNR Val: 37.48, SSIM Train: 0.9693, SSIM Val: 0.9656
# Epoch [28/50] - Train Loss: 0.0086, Val Loss: 0.0096, PSNR Train: 38.42, PSNR Val: 37.49, SSIM Train: 0.9696, SSIM Val: 0.9658
# Epoch [29/50] - Train Loss: 0.0086, Val Loss: 0.0096, PSNR Train: 38.43, PSNR Val: 37.52, SSIM Train: 0.9696, SSIM Val: 0.9658
# Epoch [30/50] - Train Loss: 0.0086, Val Loss: 0.0095, PSNR Train: 38.45, PSNR Val: 37.53, SSIM Train: 0.9697, SSIM Val: 0.9659
# Epoch [31/50] - Train Loss: 0.0086, Val Loss: 0.0096, PSNR Train: 38.46, PSNR Val: 37.50, SSIM Train: 0.9697, SSIM Val: 0.9653
# Epoch [32/50] - Train Loss: 0.0086, Val Loss: 0.0096, PSNR Train: 38.47, PSNR Val: 37.49, SSIM Train: 0.9697, SSIM Val: 0.9658
# Epoch [33/50] - Train Loss: 0.0086, Val Loss: 0.0095, PSNR Train: 38.48, PSNR Val: 37.54, SSIM Train: 0.9698, SSIM Val: 0.9660
# Epoch [34/50] - Train Loss: 0.0086, Val Loss: 0.0095, PSNR Train: 38.48, PSNR Val: 37.53, SSIM Train: 0.9698, SSIM Val: 0.9659
# Epoch [35/50] - Train Loss: 0.0086, Val Loss: 0.0095, PSNR Train: 38.50, PSNR Val: 37.55, SSIM Train: 0.9699, SSIM Val: 0.9660
# Epoch [36/50] - Train Loss: 0.0086, Val Loss: 0.0095, PSNR Train: 38.51, PSNR Val: 37.56, SSIM Train: 0.9700, SSIM Val: 0.9659
# Epoch [37/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.52, PSNR Val: 37.55, SSIM Train: 0.9700, SSIM Val: 0.9654
# Epoch [38/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.53, PSNR Val: 37.57, SSIM Train: 0.9700, SSIM Val: 0.9661
# Epoch [39/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.53, PSNR Val: 37.58, SSIM Train: 0.9700, SSIM Val: 0.9662
# Epoch [40/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.55, PSNR Val: 37.58, SSIM Train: 0.9702, SSIM Val: 0.9662
# Epoch [41/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.55, PSNR Val: 37.59, SSIM Train: 0.9700, SSIM Val: 0.9661
# Epoch [42/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.56, PSNR Val: 37.60, SSIM Train: 0.9702, SSIM Val: 0.9663
# Epoch [43/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.56, PSNR Val: 37.60, SSIM Train: 0.9701, SSIM Val: 0.9662
# Epoch [44/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.58, PSNR Val: 37.60, SSIM Train: 0.9703, SSIM Val: 0.9663
# Epoch [45/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.58, PSNR Val: 37.61, SSIM Train: 0.9703, SSIM Val: 0.9662
# Epoch [46/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.58, PSNR Val: 37.61, SSIM Train: 0.9703, SSIM Val: 0.9662
# Epoch [47/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.59, PSNR Val: 37.62, SSIM Train: 0.9703, SSIM Val: 0.9663
# Epoch [48/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.59, PSNR Val: 37.62, SSIM Train: 0.9703, SSIM Val: 0.9661
# Epoch [49/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.60, PSNR Val: 37.60, SSIM Train: 0.9703, SSIM Val: 0.9661
# Epoch [50/50] - Train Loss: 0.0085, Val Loss: 0.0095, PSNR Train: 38.61, PSNR Val: 37.62, SSIM Train: 0.9704, SSIM Val: 0.9664
# Entrenamiento completado.

# %%
# Se guarda el modelo final
save_path = "EDSRD3D_final.pth"

# Guarda los pesos del modelo
torch.save(model.state_dict(), save_path)

print(f"Modelo guardado en {save_path}")
# Out:
# Modelo guardado en EDSRD3D_final.pth

# %% [markdown]
# EL ENTRENAMIENTO DURO 8 HORAS Y 24 MINUTOS

# %%
# Leer los datos del archivo HDF5
with h5py.File(h5_file, "r") as f:
    train_losses = f["train_loss"][:]
    val_losses = f["val_loss"][:]
    psnr_train = f["psnr_train"][:]
    psnr_val = f["psnr_val"][:]
    ssim_train = f["ssim_train"][:]
    ssim_val = f["ssim_val"][:]

# Crear el rango de épocas
epochs = range(1, len(train_losses) + 1)

# Graficar las métricas
plt.figure(figsize=(18, 5))

# Gráfico de la función de pérdida
plt.subplot(1, 3, 1)
plt.plot(epochs, train_losses, 'r-', label="Train Loss")
plt.plot(epochs, val_losses, 'b-', label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Evolución de la Pérdida")
plt.legend()

# Gráfico de PSNR
plt.subplot(1, 3, 2)
plt.plot(epochs, psnr_train, 'r-', label="PSNR de entrenamiento")
plt.plot(epochs, psnr_val, 'b-', label="PSNR de validación")
plt.xlabel("Epochs")
plt.ylabel("PSNR (dB)")
plt.title("Evolución del PSNR")
plt.legend()

# Gráfico de SSIM
plt.subplot(1, 3, 3)
plt.plot(epochs, ssim_train, 'r-', label="SSIM de entrenamiento")
plt.plot(epochs, ssim_val, 'b-', label="SSIM de validación")
plt.xlabel("Epochs")
plt.ylabel("SSIM")
plt.title("Evolución del SSIM")
plt.legend()

plt.tight_layout()
plt.show()
